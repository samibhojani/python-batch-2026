# %% [markdown]
# # Functions

# %%
# named reusable block of code 

# built in functions 

print("Hi")
len("world")
int("955")
range(20)
# Out:
# Hi
# range(0, 20)

# %%
# today we build our own funciton 


# define a function --
# calls function
# every returns a value
# syntax 

# def function_name():
    # function code

# %%
# defining a function 

def greet():
    print("Good Morning! Have a great day")

# %%
# calling function
greet()
greet()
greet()
greet()
greet()
greet()
greet()
greet()
# Out:
# Good Morning! Have a great day
# Good Morning! Have a great day
# Good Morning! Have a great day
# Good Morning! Have a great day
# Good Morning! Have a great day
# Good Morning! Have a great day
# Good Morning! Have a great day
# Good Morning! Have a great day

# %%
def show_status():
    print("All good pipelines are running successfully!")
    print("Records loaded: 4500")

show_status()
# Out:
# All good pipelines are running successfully!
# Records loaded: 4500

# %% [markdown]
# # Parameters & Arguments

# %%
# Good Morning Zafar! Have a good day
# Good Morning Zaman! Have a good day

# paramters is a variable  the accepts as an input

# argument is a value that you pass

def greet(name): # parameter
    print(f"Good Morning {name} ! Have a great day")

greet("Zafar") # zafar is an argument
greet("Ayan") # ayan is an argument
greet("Zaman")
# Out:
# Good Morning Zafar ! Have a great day
# Good Morning Ayan ! Have a great day
# Good Morning Zaman ! Have a great day

# %%
students = ["Abdullah", "Ibad", "Sufyan","Hamza"]

for student in students:
    greet(student)
# Out:
# Good Morning Abdullah ! Have a great day
# Good Morning Ibad ! Have a great day
# Good Morning Sufyan ! Have a great day
# Good Morning Hamza ! Have a great day

# %% [markdown]
# ### Positional Arguments

# %%
def introduction(name, age, city): # 3 parameters
    print(f"Name is {name}, age is {age}, city is {city }")

introduction("Ayan", 50, "Karachi")
# Out:
# Name is Ayan, age is 50, city is Karachi

# %%
introduction("Ayan", "Kar" , 50) # positional arguments name first per hai ... argument value bhi 1st honi chayai hai
# Out:
# Name is Ayan, age is Kar, city is 50

# %% [markdown]
# ### Keyword Arguments

# %%
def introduction(name, age, city): # 3 parameters
    print(f"Name is {name}, age is {age}, city is {city }")

introduction(name="Ayan", city='Quetta', age=40)
introduction(city='Quetta', name="Ayan", age=40)
# Out:
# Name is Ayan, age is 40, city is Quetta
# Name is Ayan, age is 40, city is Quetta

# %% [markdown]
# ### Return

# %%
def greet(): # if no return statement then it return null
    print("Good Morning! Have a great day")

value = greet()
print(value) # functions return none
# Out:
# Good Morning! Have a great day
# None

# %%
def greet(): # if no return statement then it return null
    print("Good Morning! Have a great day")
    return None

value = greet()
print(value) # functions return none
# Out:
# Good Morning! Have a great day
# None

# %%
def sum(a,b):
    # print(a+b)
    ans = a + b
    return ans    # or return a + b

def multiply(c,d):
    return c * d

a = 10 
b = 5

c = sum(a,b)
print("sum value is ", c)
d = 2

answer = multiply(c,d)
print("total answer is " , answer)
# Out:
# sum value is  15
# total answer is  30

# %%
# Task -- calculate grade of student s

# 90+ A+
# 80 - 90 -- A
# 70 - 80 B 
# 60 - 70 - C

# define a function get_grade(marks)


students = [
    {"name": "Ali", "score": 92},
    {"name": "Sara", "score": 75},
    {"name": "Ahmed", "score": 55},
    {"name": "Zara", "score": 88}
]

# %%
# Write get_grade(score) that returns a letter grade.
# Then loop over a list of students and print each result.

def get_grade(score):
    if score >= 90:
        return "A"
    elif score >= 80:
        return "B"
    elif score >= 70:
        return "C"
    elif score >= 60:
        return "D"
    else:
        return "F"

students = [
    {"name": "Ali", "score": 92},
    {"name": "Sara", "score": 75},
    {"name": "Ahmed", "score": 55},
    {"name": "Zara", "score": 88}
]

for student in students:
    grade = get_grade(student["score"])
    print(f"{student['name']} got grade {grade}")
# Out:
# Ali got grade A
# Sara got grade C
# Ahmed got grade F
# Zara got grade B

# %% [markdown]
# # Default Arguments

# %%
def introduction(name, age = 25, city = 'Karachi'): # 3 parameters - city is default parameter
    print(f"Name is {name}, age is {age}, city is {city }")

introduction("Ayan", 20 , "Hyderabad")
introduction("Moosa", 35)
introduction("Zaman")
# Out:
# Name is Ayan, age is 20, city is Hyderabad
# Name is Moosa, age is 35, city is Karachi
# Name is Zaman, age is 25, city is Karachi

# %%
# calculate tax
# food amount - 
# tax percentage - 15% 

# calculate biling amount 

# 100 rs -- 15 -- 100 + 15 == 115



# class work 
# Build a receipt system using multiple functions that call each other.

# 1 function calculate_tax 
# 2 function calculate discount -- 8% 
# 3 function caluculate total 
# 4th function print_receipt - tax, dicount payment

# 10000 + 1000 -2000 = 9000

# %% [markdown]
# ### Functions Scopes

# %%
# scope means where a variable can be seen and used 

# local scope: variables created inside function - they only exists inside function, we can't call them outside

# %%
def sum(a,b):
    answer_1 =  a + b # variable initiated inside a function -- local scope
    return answer_1

sum(10,6)
print(answer_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[67], line 6
#       3     return answer_1
#       5 sum(10,6)
# ----> 6 print(answer_1)
#
# NameError: name 'answer_1' is not defined

# %%
count = 10 

def increment():
    count = 100 # ik new variable banaya inside a function
    return count

increment()
print(count)
# Out:
# 10

# %%
count = 10 
# global scope

def increment():
    global count
    count = count + 10 # new variable initialize nhi kare ga 
    return count

increment()
print(count)
# Out:
# 20
