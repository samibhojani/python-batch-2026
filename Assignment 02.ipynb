# %% [markdown]
# # Part -2 Python Basics (Conditional Statements)

# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
#Type your code here
employee_name = input("Enter employee name: ")
employee_salary = float(input("Enter employee salary: "))
employee_service_years = int(input("Enter employee service years: "))

if employee_service_years > 5:
    bonus = employee_salary * 0.05
else:
    bonus = 0

print(f"Employee Name: {employee_name.title()}\nEmployee Salary: {employee_salary}\nEmployee Service Years: {employee_service_years}\nBonus: {bonus}\nReceiveable Amount: {bonus + employee_salary}")
# Out:
# Employee Name: Sami Bhojani
# Employee Salary: 150000.0
# Employee Service Years: 7
# Bonus: 7500.0
# Receiveable Amount: 157500.0

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
#Type your code here
name = input("Enter your name: ")
age = int(input("Enter your age: "))

if age >= 18:
    print(f"{name.title()}, you are eligible to vote.")
else:
    print(f"{name.title()}, you are not eligible to vote.")
# Out:
# Sami, you are eligible to vote.

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
#Type your code here
number = int(input("Enter a number: "))
if number % 2 == 0:
    print(f"{number} is an even number.")
else:
    print(f"{number} is an odd number.")
# Out:
# 7 is an odd number.

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
#Type your code here
div_number = int(input("Enter a number to check divisibility: "))
if div_number % 7 == 0:
    print(f"{div_number} is divisible by 7.")
# Out:
# 7 is divisible by 7.

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
#Type your code here
multiple_of_five = int(input("Enter a number: "))
if multiple_of_five % 5 == 0:
    print('Hello!')
else:
    print('Bye!')
# Out:
# Bye!

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
#Type your code here
num_ld = int(input("Enter a number: "))
if num_ld < 0:
    print("Please enter a positive number.")
else:
    last_digit = num_ld % 10
    print(f"Last digit of {num_ld}, is: {last_digit}")
# Out:
# Last digit of 12345, is: 5

# %% [markdown]
# 9) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
#Type your code here 
length = float(input("Enter length: "))
breadth = float(input("Enter breadth: "))

if length == breadth:
    print("It is a Square")
else:
    print("It is a Rectangle")
# Out:
# It is a Square

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
# Type your code here
value1 = int(input("Enter first number: "))
value2 = int(input("Enter second number: "))
if value1 > value2:
    print(f"{value1} is greater than {value2}.")
elif value2 > value1:
    print(f"{value2} is greater than {value1}.")
elif value1 == value2:
    print(f"{value1} is equal to {value2}.")
else:
    print("Invalid input.")
# Out:
# 20 is greater than 10.

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
#Type your code here
product_quantity = int(input("Enter product quantity: "))
product_cost = 100
cost_of_purchase_quantity = product_quantity * product_cost
if cost_of_purchase_quantity > 1000:
    discount = cost_of_purchase_quantity * 0.1
    print(f"Quantity: {product_quantity},\nCost: {cost_of_purchase_quantity},\nDiscount applied: {discount}")
else:
    print(f"Cost: {cost_of_purchase_quantity},\nNo discount applied!")
# Out:
# Quantity: 12,
# Cost: 1200,
# Discount applied: 120.0

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
#Type your code here
marks = int(input("Enter your marks: "))
if marks >= 80 and marks <= 100:
    print("Grade: A")
elif marks >= 60 and marks < 80:
    print("Grade: B")
elif marks >= 50 and marks < 60:
    print("Grade: C")
elif marks >= 45 and marks < 50:
    print("Grade: D")
elif marks >= 25 and marks < 45:
    print("Grade: E")
else:
    print("Grade: F")
# Out:
# Grade: A

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# - Number of classes held
#
# - Number of classes attended.
#
# And print
#
# - percentage of class attended
#
# - Is student is allowed to sit in exam or not.

# %%
#Type your code here
classes_held = int(input("Enter number of classes held: "))
classes_attended = int(input("Enter number of classes attended: "))
attendance_percentage = (classes_attended / classes_held) * 100
if attendance_percentage >= 75:
    print(f"Attendance Percentage: {attendance_percentage:.2f}%\nYou are allowed to sit in the exam.")
else:
    print(f"Attendance Percentage: {attendance_percentage:.2f}%\nYou are not allowed to sit in the exam.")
# Out:
# Attendance Percentage: 66.67%
# You are not allowed to sit in the exam.

# %% [markdown]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
#Type your code here
#Type your code here
classes_held = int(input("Enter number of classes held: "))
classes_attended = int(input("Enter number of classes attended: "))
medical_cause = input("Do you have a medical cause? (yes/no): ").strip().lower()
attendance_percentage = (classes_attended / classes_held) * 100
if attendance_percentage >= 75:
    print(f"Attendance Percentage: {attendance_percentage:.2f}%\nYou are allowed to sit in the exam.")
else:
    if medical_cause == "yes":
        print(f"Attendance Percentage: {attendance_percentage:.2f}%\nYou are allowed to sit in the exam due to medical cause.")
    else:
        print(f"Attendance Percentage: {attendance_percentage:.2f}%\nYou are not allowed to sit in the exam.")
# Out:
# Attendance Percentage: 66.67%
# You are allowed to sit in the exam due to medical cause.

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
#Type your code here
year = int(input("Enter a year: "))
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a leap year.")
else:
    print(f"{year} is not a leap year.")
# Out:
# 2000 is a leap year.

# %% [markdown]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
#Type your code here
gender = input("Enter your sex (M/F): ").strip().upper()
age = int(input("Enter your age: "))
if gender == "M" and age >= 20 and age <= 40:
    print(f"Employee Gender: {gender}\nEmployee Age: {age}\nEmployee is eligible to work anywhere.")
elif gender == "F" or (gender == "M" and (age >= 40 or age <= 60)):
    print(f"Employee Gender: {gender}\nEmployee Age: {age}\nEmployee is eligible to work in urban areas only.")
else:
    print("ERROR: Invalid age or gender input. Please check the values entered.")
# Out:
# Employee Gender: M
# Employee Age: 31
# Employee is eligible to work anywhere.

# %% [markdown]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %%
#Type your code here
no_of_units = int(input("Enter number of units consumed: "))
if no_of_units <= 100:
    print(f"Units Consumed: {no_of_units}\nNO CHARGE")
elif no_of_units > 100 and no_of_units <= 200:
    charge = (no_of_units) * 5
    print(f"Units Consumed: {no_of_units}\nCharge: {charge}")
elif no_of_units > 200:
    charge = (no_of_units) * 10
    print(f"Units Consumed: {no_of_units}\nCharge: {charge}")
# Out:
# Units Consumed: 350
# Charge: 3500

# %% [markdown]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
#Type your code here
p1_age = int(input("Enter age of person 1: "))
p2_age = int(input("Enter age of person 2: "))
p3_age = int(input("Enter age of person 3: "))
if p1_age > p2_age and p1_age > p3_age:
    print(f"Person 1 is the oldest with age: {p1_age}")
elif p2_age > p1_age and p2_age > p3_age:
    print(f"Person 2 is the oldest with age: {p2_age}")
elif p3_age > p1_age and p3_age > p2_age:
    print(f"Person 3 is the oldest with age: {p3_age}")
# Out:
# Person 3 is the oldest with age: 32
